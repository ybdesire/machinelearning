# %% [markdown]
# # 1. 基本读入、显示

# %% [markdown]
# ## 1.1 读入图像，查看信息

# %%
import numpy as np
import cv2

# read image
img = cv2.imread('lena.jpg', cv2.IMREAD_COLOR)# IMREAD_GRAYSCALE, IMREAD_COLOR

# %%
img.shape
# Out:
# (225, 400, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# ## 1.2 图像显示：灰度图

# %%
img = cv2.imread('lena.jpg', cv2.IMREAD_GRAYSCALE)# IMREAD_GRAYSCALE, IMREAD_COLOR

# %%
# %matplotlib inline

from matplotlib import pyplot as plt

plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# ## 1.3 图像显示：彩色图

# %%
# OpenCV follows BGR order, while matplotlib likely follows RGB order
# more details here: http://stackoverflow.com/questions/15072736/extracting-a-region-from-an-image-using-slicing-in-python-opencv/15074748#15074748
img = cv2.imread('lena.jpg', cv2.IMREAD_COLOR)# IMREAD_GRAYSCALE, IMREAD_COLOR

img2 = img[:,:,::-1]

# %%
# %matplotlib inline

from matplotlib import pyplot as plt

plt.imshow(img2)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# ## 1.4 图像转换BGR 2 RGB

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# Display BGR
img = cv2.imread('lena.jpg', cv2.IMREAD_COLOR)# IMREAD_GRAYSCALE, IMREAD_COLOR

plt.imshow(img)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# Display BGR
img = cv2.imread('lena.jpg', cv2.IMREAD_COLOR)# IMREAD_GRAYSCALE, IMREAD_COLOR
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # cv2默认为bgr顺序

plt.imshow(img2)
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# # 2. 查看图像二维矩阵

# %% [markdown]
# ## 2.1 灰度图

# %%
img = cv2.imread('lena.jpg', cv2.IMREAD_GRAYSCALE)# IMREAD_GRAYSCALE, IMREAD_COLOR

# %%
# %matplotlib inline

from matplotlib import pyplot as plt

plt.subplot(1, 2, 1) 
plt.title('original')
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()


plt.subplot(1, 2, 2) 
plt.title('scaled')
plt.imshow(img[50:150, 100:300], cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
