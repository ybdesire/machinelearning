# %% [markdown]
# # 1. how to use pklearn

# %%
#! git clone https://github.com/chasembowers/poker-learn.git
# Out:
# Cloning into 'poker-learn'...

# %%
# chdir to poker-learn

# %%
# auto play the game

from pklearn import Table
from pklearn.templates import simulate, BasicPlayer
from sklearn.ensemble import GradientBoostingRegressor


t = Table(smallBlind=1, bigBlind=2, maxBuyIn=200)

for i in range(6):
    
    r = GradientBoostingRegressor()
    name = 'Player ' + str(i+1)
    p = BasicPlayer(name=name, reg=r, bankroll=10**6, nRaises=10, rFactor=.7, memory=10**5)
    t.addPlayer(p)

simulate(t, nHands=10000, firstTrain=2000, nTrain=1000, nBuyIn=10)
simulate(t, nHands=20, nBuyIn=10, vocal=True)
# Out:
# Beginning simulation of 10000 hands.
# Players are training...
# Complete.
# 2801 hands simulated.
# Players are training...
# Complete.
# 3883 hands simulated.
# Players are training...
# Complete.
# 4461 hands simulated.
# Players are training...
# Complete.
# 5000 hands simulated.
# Players are training...
# Complete.
# 5999 hands simulated.
# Players are training...
# Complete.
# 7000 hands simulated.
# Players are training...
# Complete.
# 8000 hands simulated.
# Players are training...
# Complete.
# 9000 hands simulated.
# Players are training...
# Complete.
# Simulation complete.
#
# Beginning simulation of 20 hands.
# Hand 1
# Player 5(200) dealt 6d and Jh
# Player 1(200) dealt 2c and 4s
# Player 4(200) dealt 5s and Qd
# Player 6(200) dealt 5d and Td
# Player 3(200) dealt Jd and 4d
# Player 2(200) dealt 9c and 7s
#
# Player 4 posts small blind of 1
# Player 6 posts big blind of 2
# Player 3 calls 2
# Player 2 calls 2
# Player 5 folds.
# Player 1 folds.
# Player 4 folds.
# Player 6 raises 5 to 7
# Player 3 raises 9 to 16
# Player 2 raises 17 to 33
# Player 6 calls 26
# Player 3 raises 151 to 184
# Player 2 calls 151
# Player 6 calls 151
#
# ['8c', '5h', '2s']
# Player 6 raises 2 to 2
# Player 3 raises 3 to 5
# Player 2 raises 6 to 11
# Player 6 calls 9
# Player 3 calls 6
#
# ['8c', '5h', '2s', '9h']
# Player 6 raises 2 to 2
# Player 3 raises all-in 3 to 5
# Player 2 all-in calls with 5
# Player 6 all-in calls with 3
#
# ['8c', '5h', '2s', '9h', 'Kh']
#
# Player 2 wins 601 from main pot
#
# Hand 2
# Player 5(200) dealt 2c and 4s
# Player 1(200) dealt 2d and 3d
# Player 4(199) dealt 7c and As
# Player 2(601) dealt Kd and 4d
#
# Player 2 posts small blind of 1
# Player 5 posts big blind of 2
# Player 1 folds.
# Player 4 raises 6 to 8
# Player 2 raises 285 to 293
# Player 5 folds.
# Player 4 all-in calls with 191
# 94 uncalled chips return to Player 2
#
# ['3h', 'Js', 'Jc']
#
# ['3h', 'Js', 'Jc', '8s']
#
# ['3h', 'Js', 'Jc', '8s', 'Kc']
#
# Player 2 wins 400 from main pot
#
# Hand 3
# Player 5(198) dealt 3h and 9s
# Player 1(200) dealt Jc and 8s
# Player 2(802) dealt 4s and 2c
#
# Player 5 posts small blind of 1
# Player 1 posts big blind of 2
# Player 2 folds.
# Player 5 folds.
# 1 uncalled chips return to Player 1
#
# Player 1 wins 2
#
# Hand 4
# Player 5(197) dealt 2s and 8d
# Player 1(201) dealt 7h and 4s
# Player 2(802) dealt Ah and 7c
#
# Player 1 posts small blind of 1
# Player 2 posts big blind of 2
# Player 5 folds.
# Player 1 folds.
# 1 uncalled chips return to Player 2
#
# Player 2 wins 2
#
# Hand 5
# Player 5(197) dealt Qd and 9s
# Player 1(200) dealt Qc and 2d
# Player 2(803) dealt 6h and 6c
#
# Player 2 posts small blind of 1
# Player 5 posts big blind of 2
# Player 1 calls 2
# Player 2 calls 1
# Player 5 raises 93 to 95
# Player 1 calls 93
# Player 2 raises 179 to 274
# Player 5 all-in calls with 102
# Player 1 all-in calls with 105
# 74 uncalled chips return to Player 2
#
# ['4h', 'Ks', '8c']
#
# ['4h', 'Ks', '8c', 'Jc']
#
# ['4h', 'Ks', '8c', 'Jc', 'Ah']
#
# Player 2 wins 591 from main pot
# Player 2 wins 6 from side pot
#
# Hand 6
# Not enough eligible players.
# Players are cashing out and buying in.
# Hand 6
# Player 2(200) dealt 4h and 2c
# Player 6(200) dealt Ad and Td
# Player 3(200) dealt 7d and 6d
# Player 4(200) dealt 7s and Jh
# Player 5(200) dealt 6c and 8d
# Player 1(200) dealt Kc and Jc
#
# Player 6 posts small blind of 1
# Player 3 posts big blind of 2
# Player 4 folds.
# Player 5 folds.
# Player 1 calls 2
# Player 2 folds.
# Player 6 calls 1
# Player 3 raises 5 to 7
# Player 1 raises 9 to 16
# Player 6 calls 14
# Player 3 folds.
#
# ['Ah', '9d', '5s']
# Player 6 checks.
# Player 1 raises 30 to 30
# Player 6 calls 30
#
# ['Ah', '9d', '5s', '9h']
# Player 6 checks.
# Player 1 raises all-in 154 to 154
# Player 6 all-in calls with 154
#
# ['Ah', '9d', '5s', '9h', 'Tc']
#
# Player 6 wins 407 from main pot
#
# Hand 7
# Player 2(200) dealt 6d and 7s
# Player 6(407) dealt 4h and 2c
# Player 3(193) dealt Js and Tc
# Player 4(200) dealt Jc and Jh
# Player 5(200) dealt Jd and Ks
#
# Player 3 posts small blind of 1
# Player 4 posts big blind of 2
# Player 5 calls 2
# Player 2 calls 2
# Player 6 raises 14 to 16
# Player 3 raises 176 to 192
# Player 4 calls 190
# Player 5 calls 190
# Player 2 folds.
# Player 6 raises 199 to 391
# Player 3 all-in calls with 1
# Player 4 all-in calls with 8
# Player 5 all-in calls with 8
# 191 uncalled chips return to Player 6
#
# ['5h', '5c', 'Kc']
#
# ['5h', '5c', 'Kc', '7d']
#
# ['5h', '5c', 'Kc', '7d', '7h']
#
# Player 5 wins 774 from main pot
# Player 5 wins 21 from side pot
#
# Hand 8
# Player 2(198) dealt Kd and 4s
# Player 6(207) dealt Ah and 4c
# Player 5(795) dealt Th and As
#
# Player 2 posts small blind of 1
# Player 6 posts big blind of 2
# Player 5 calls 2
# Player 2 folds.
# Player 6 raises 47 to 49
# Player 5 raises 744 to 793
# Player 6 all-in calls with 158
# 586 uncalled chips return to Player 5
#
# ['6c', '8d', 'Tc']
#
# ['6c', '8d', 'Tc', 'Jh']
#
# ['6c', '8d', 'Tc', 'Jh', '7d']
#
# Player 5 wins 415 from main pot
#
# Hand 9
# Player 2(197) dealt 9s and 6c
# Player 5(1003) dealt As and Js
#
# Player 2 posts small blind of 1
# Player 5 posts big blind of 2
# Player 2 folds.
# 1 uncalled chips return to Player 5
#
# Player 5 wins 2
#
# Hand 10
# Player 2(196) dealt 6c and 2d
# Player 5(1004) dealt Kd and Jd
#
# Player 5 posts small blind of 1
# Player 2 posts big blind of 2
# Player 5 raises 55 to 57
# Player 2 folds.
# 55 uncalled chips return to Player 5
#
# Player 5 wins 4
#
# Hand 11
# Player 2(194) dealt 3c and 9c
# Player 5(1006) dealt 8d and 8s
#
# Player 2 posts small blind of 1
# Player 5 posts big blind of 2
# Player 2 folds.
# 1 uncalled chips return to Player 5
#
# Player 5 wins 2
#
# Hand 12
# Player 2(193) dealt 3s and Qh
# Player 5(1007) dealt Ts and 7s
#
# Player 5 posts small blind of 1
# Player 2 posts big blind of 2
# Player 5 folds.
# 1 uncalled chips return to Player 2
#
# Player 2 wins 2
#
# Hand 13
# Player 2(194) dealt 3s and Kd
# Player 5(1006) dealt 2c and 9d
#
# Player 2 posts small blind of 1
# Player 5 posts big blind of 2
# Player 2 folds.
# 1 uncalled chips return to Player 5
#
# Player 5 wins 2
#
# Hand 14
# Player 2(193) dealt 7c and 3c
# Player 5(1007) dealt 6h and 7h
#
# Player 5 posts small blind of 1
# Player 2 posts big blind of 2
# Player 5 folds.
# 1 uncalled chips return to Player 2
#
# Player 2 wins 2
#
# Hand 15
# Player 2(194) dealt 8h and 3h
# Player 5(1006) dealt 9d and 8d
#
# Player 2 posts small blind of 1
# Player 5 posts big blind of 2
# Player 2 folds.
# 1 uncalled chips return to Player 5
#
# Player 5 wins 2
#
# Players are cashing out and buying in.
# Hand 16
# Player 2(200) dealt 2s and 9c
# Player 5(200) dealt 7h and 6s
# Player 1(200) dealt 9s and 7d
# Player 3(200) dealt 8h and Td
# Player 4(200) dealt 5c and Kh
# Player 6(200) dealt 4s and 9h
#
# Player 1 posts small blind of 1
# Player 3 posts big blind of 2
# Player 4 folds.
# Player 6 calls 2
# Player 2 folds.
# Player 5 folds.
# Player 1 folds.
# Player 3 raises 136 to 138
# Player 6 calls 136
#
# ['3s', 'Qs', 'Jc']
# Player 3 raises 21 to 21
# Player 6 calls 21
#
# ['3s', 'Qs', 'Jc', 'Ad']
# Player 3 raises 20 to 20
# Player 6 calls 20
#
# ['3s', 'Qs', 'Jc', 'Ad', 'Qd']
# Player 3 raises all-in 21 to 21
# Player 6 all-in calls with 21
#
# Player 3 wins 401 from main pot
#
# Hand 17
# Player 2(200) dealt 9d and 3h
# Player 5(200) dealt 8s and Jc
# Player 1(199) dealt Td and Qh
# Player 3(401) dealt 6h and 8c
# Player 4(200) dealt Ts and Qs
#
# Player 3 posts small blind of 1
# Player 4 posts big blind of 2
# Player 2 calls 2
# Player 5 folds.
# Player 1 raises 6 to 8
# Player 3 raises 187 to 195
# Player 4 folds.
# Player 2 folds.
# Player 1 calls 187
#
# ['6c', '5s', '7h']
# Player 3 raises 144 to 144
# Player 1 all-in calls with 4
# 140 uncalled chips return to Player 3
#
# ['6c', '5s', '7h', '8d']
#
# ['6c', '5s', '7h', '8d', '7c']
#
# Player 3 wins 402 from main pot
#
# Hand 18
# Player 2(198) dealt Js and 6d
# Player 5(200) dealt 8c and 7d
# Player 3(604) dealt 4c and Qd
# Player 4(198) dealt 3h and 4s
#
# Player 4 posts small blind of 1
# Player 2 posts big blind of 2
# Player 5 folds.
# Player 3 calls 2
# Player 4 folds.
# Player 2 raises 5 to 7
# Player 3 calls 5
#
# ['9h', 'Jh', '7h']
# Player 2 raises 7 to 7
# Player 3 raises 17 to 24
# Player 2 raises 39 to 63
# Player 3 raises 74 to 137
# Player 2 calls 74
#
# ['9h', 'Jh', '7h', '5h']
# Player 2 raises all-in 54 to 54
# Player 3 raises 268 to 322
# 268 uncalled chips return to Player 3
#
# ['9h', 'Jh', '7h', '5h', '8d']
#
# Player 2 wins 397 from main pot
#
# Hand 19
# Player 2(397) dealt Qd and 8c
# Player 5(200) dealt 3d and 2d
# Player 3(406) dealt Qh and 4c
# Player 4(197) dealt 4h and 3s
#
# Player 2 posts small blind of 1
# Player 5 posts big blind of 2
# Player 3 calls 2
# Player 4 folds.
# Player 2 raises 192 to 194
# Player 5 folds.
# Player 3 raises 210 to 404
# Player 2 all-in calls with 203
# 7 uncalled chips return to Player 3
#
# ['9c', '4d', '7d']
#
# ['9c', '4d', '7d', '7c']
#
# ['9c', '4d', '7d', '7c', 'Kh']
#
# Player 3 wins 796 from main pot
#
# Hand 20
# Player 5(198) dealt 7d and Jh
# Player 3(805) dealt Ah and 4c
# Player 4(197) dealt 6c and 9h
#
# Player 3 posts small blind of 1
# Player 4 posts big blind of 2
# Player 5 folds.
# Player 3 raises 273 to 275
# Player 4 folds.
# 273 uncalled chips return to Player 3
#
# Player 3 wins 4
#
# Simulation complete.
# [[1053044,
#   1053044,
#   1053044,
#   1053044,
#   1053044,
#   1052844,
#   1052844,
#   1052844,
#   1052844,
#   1052844,
#   1052844,
#   1052844,
#   1052844,
#   1052844,
#   1052844,
#   1052644,
#   1052644,
#   1052644,
#   1052644,
#   1052644],
#  [1007014,
#   1007014,
#   1007014,
#   1007014,
#   1007014,
#   1008014,
#   1008014,
#   1008014,
#   1008014,
#   1008014,
#   1008014,
#   1008014,
#   1008014,
#   1008014,
#   1008014,
#   1008007,
#   1008007,
#   1008007,
#   1008007,
#   1008007],
#  [975860,
#   975860,
#   975860,
#   975860,
#   975860,
#   975660,
#   975660,
#   975660,
#   975660,
#   975660,
#   975660,
#   975660,
#   975660,
#   975660,
#   975660,
#   975460,
#   975460,
#   975460,
#   975460,
#   975460],
#  [1001271,
#   1001271,
#   1001271,
#   1001271,
#   1001271,
#   1001071,
#   1001071,
#   1001071,
#   1001071,
#   1001071,
#   1001071,
#   1001071,
#   1001071,
#   1001071,
#   1001071,
#   1000871,
#   1000871,
#   1000871,
#   1000871,
#   1000871],
#  [939923,
#   939923,
#   939923,
#   939923,
#   939923,
#   939723,
#   939723,
#   939723,
#   939723,
#   939723,
#   939723,
#   939723,
#   939723,
#   939723,
#   939723,
#   940530,
#   940530,
#   940530,
#   940530,
#   940530],
#  [1021688,
#   1021688,
#   1021688,
#   1021688,
#   1021688,
#   1021488,
#   1021488,
#   1021488,
#   1021488,
#   1021488,
#   1021488,
#   1021488,
#   1021488,
#   1021488,
#   1021488,
#   1021288,
#   1021288,
#   1021288,
#   1021288,
#   1021288]]

# %% [markdown]
# # 2. Feature/Label

# %% [markdown]
# ## 2.1 get blank feature and label if the player not trained.

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
from pklearn import Table
from pklearn.templates import simulate, BasicPlayer
from sklearn.ensemble import GradientBoostingRegressor

# get blank feature and label if the player not trained.
player = BasicPlayer(name='player_name', reg=GradientBoostingRegressor(), bankroll=10**6, nRaises=10, rFactor=.7, memory=10**5)
print(player.getFeatures(), player.getLabels())
# Out:
# ([], [])

# %% [markdown]
# ## 2.2 create player, then play the game, then we can get feature

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
from pklearn import Table
from pklearn.templates import simulate, BasicPlayer
from sklearn.ensemble import GradientBoostingRegressor

# create player, then play the game
from pklearn import Table
from pklearn.templates import simulate, BasicPlayer
from sklearn.ensemble import GradientBoostingRegressor


t = Table(smallBlind=1, bigBlind=2, maxBuyIn=200)
player_list = []
for i in range(10):
    
    r = GradientBoostingRegressor()
    name = 'Player ' + str(i+1)
    p = BasicPlayer(name=name, reg=r, bankroll=10**6, nRaises=10, rFactor=.7, memory=10**5)
    t.addPlayer(p)
    player_list.append(p)

simulate(t, nHands=1000, firstTrain=200, nTrain=1000, nBuyIn=10)
