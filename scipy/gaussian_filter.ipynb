# %%
data = [1.558 ,1.5436 ,1.558 ,1.5556 ,1.5747 ,1.5747 ,1.5604 ,1.5699 ,1.5532 ,1.4935 ,1.4863 ,1.4719 ,1.4361 ,1.5317 ,1.546 ,1.5078 ,
        1.5054 ,1.4672 ,1.4743 ,1.4481 ,1.4552 ,1.5293 ,1.5078 ,1.5771 ,1.5747 ,1.5675 ,1.5771 ,1.6034 ,1.6105 ,1.5938 ,1.5843 ,1.5866 ,
        1.5484 ,1.5293 ,1.5245 ,1.5389 ,1.5197 ,1.4911 ,1.5173 ,1.503 ,1.4719 ,1.4624 ,1.4528 ,1.4313 ,1.417 ,1.4265 ,1.417 ,1.4194 ,
        1.3238 ,1.2808 ,1.2903 ,1.2903 ,1.2664 ,1.2664 ,1.2187 ,1.2449 ,1.3381 ,1.2951 ,1.3118 ,1.3405 ,1.4743 ,1.6225 ,1.6583 ,1.5866 ,
        1.644 ,1.5771 ,1.5843 ,1.5365 ,1.6129 ,1.5843 ,1.5843 ,1.4289 ,1.3835 ,1.4457 ,1.3668 ,1.405 ,1.4815 ,1.4552 ,1.5078 ,1.4791 ,
        1.4791 ,1.4385 ,1.4098 ,1.4481 ,1.4672 ,1.4815 ,1.4839 ,1.4242 ,1.4719 ,1.4743 ,1.4672 ,1.4696 ,1.4576 ,1.4361 ,1.4218 ,1.3811 ,
        1.3931 ,1.4194 ,1.4194 ,1.5508 ]

# %%
from scipy.ndimage.filters import gaussian_filter

data_filter = gaussian_filter(data, sigma=5) # signa: the bigger, the stronger filter

# %%
import matplotlib
import matplotlib.pyplot as plt

#matplotlib.rcParams['figure.figsize'] = (50.0, 10.0)


plt.xlabel('x')
plt.ylabel('y')
plt.title('gaussian_filter')

plt.plot(range(len(data_filter)), data_filter, 'r', linewidth=5) # red line
plt.plot(range(len(data)), data, 'b') # blue line

plt.show()
